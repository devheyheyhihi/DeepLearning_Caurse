# %%
# !mkdir 'ch03'
# !cd 'ch03/'
import os
print(os.listdir('./'))
# Out:
# mkdir: cannot create directory ‘ch03’: File exists
# ['.config', 'ch03', 'sample_data']

# %%
import sys
sys.path.append(os.pardir)
from dataset.mnist
