# %%
import tensorflow as tf

hello = tf.constant('Hello, TensorFlow!')

sess = tf.Session()
print(sess.run(hello))

a = tf.constant(10)
b = tf.constant(32)
print(sess.run(a+b))

sess.close()
# Out:
# b'Hello, TensorFlow!'
# 42

# %%
from keras.models import Sequential
model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-50589a3af17d> in <module>
# ----> 1 from keras.models import Sequential
#       2 model = Sequential()
#
# ModuleNotFoundError: No module named 'keras'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5e86ccd9667b> in <module>
# ----> 1 predicted_value = build_ANN(x)
#
# <ipython-input-7-0973151bb9d6> in build_ANN(x)
#       6     W2 = tf.Variable(tf.random_normal(shape=[hidden1_size, hidden2_size]))
#       7     b2 = tf.Variable(tf.random_normal(shape=[hidden2_size]))
# ----> 8     H2_ouput = tf.nn.relu(tf.matmul(H1_output,W2)+b2)
#       9
#      10     W3 = tf.Variable(tf.random_normal(shape=[hidden1_size, hidden2_size]))
#
# NameError: name 'H1_output' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2932fd8cb945> in <module>
# ----> 1 loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=predicted_value, labels = y))
#
# NameError: name 'predicted_value' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3c1d2bf0557d> in <module>
# ----> 1 train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
#
# NameError: name 'loss' is not defined
