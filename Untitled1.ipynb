# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63e52cb12a77> in <module>()
# ----> 1 model.compile(optimizer='rmsprop',
#       2               loss='categorical_crossentropy',
#       3               metrics=['accuracy'])
#
# NameError: name 'model' is not defined
